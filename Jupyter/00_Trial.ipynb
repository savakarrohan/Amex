# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
add_event = pd.read_parquet("../data/unadultered/add_event.parquet")
add_trans = pd.read_parquet("../data/unadultered/add_trans.parquet")
offer_metadata = pd.read_parquet("../data/unadultered/offer_metadata.parquet")
test_data = pd.read_parquet("../data/unadultered/test_data.parquet")
train_data = pd.read_parquet("../data/unadultered/train_data.parquet")

# %%
add_event.head()
# Out:
#        id2     id3    id6                      id4   id7
# 0  2431360  618619  Tiles  2023-10-22 08:08:17.768  None
# 1  2431360  363153  Tiles  2023-10-22 08:08:18.921  None
# 2  2431360   97193  Tiles  2023-10-22 08:08:17.765  None
# 3  2431360  654444  Tiles  2023-10-22 08:08:17.737  None
# 4  2431360   32325  Tiles  2023-10-22 08:08:17.812  None

# %%
add_trans.head()
# Out:
#        id2   f367 f368 f369        f370      f371    f372       id8 f374
# 0  2896709  15.60  PBR    D  2023-10-16  19:16:52  202310  59639998  DSE
# 1  2855047   6.40   PR    D  2023-10-14  13:01:16  202310  59639998  DSE
# 2  2497175  13.99  PBR    D  2023-10-14  00:31:48  202310  59639998  DSE
# 3  2655364  15.14  PGC    D  2023-10-13  12:37:25  202310  59639998  DSE
# 4  2855047   2.12   PR    D  2023-10-09  16:51:21  202310  59639998  DSE

# %%
offer_metadata.head()
# Out:
#          id3   id9  f375   f376  f377 id10  id11 f378  f374   id8  \
# 0      70687  FO5O     2    5.0  None    1  None    N  None  None
# 1  900002526   UGE     2  100.0  None    1  None    N  None  None
# 2  900002864   UTP     1  100.0  None    1  None    N  None  None
# 3      19508     o     2    NaN  None    1  None    N  None  None
# 4      35903     o     2    NaN  None    1  None    N  None  None
#
#                   id12                 id13
# 0  2018-01-01 00:00:00  2099-12-31 23:59:59
# 1  2014-10-20 00:00:00  2099-12-31 23:59:59
# 2  2016-07-19 00:00:00  2099-12-31 23:59:59
# 3  2019-06-02 17:00:00  2028-12-31 16:59:59
# 4  2019-06-02 17:00:00  2028-12-31 16:59:59

# %%
test_data.index
# Out:
# Index([ 46756,  57819,  15390, 145730, 146085,  77784, 175314,  22541, 122552,
#         95726,
#        ...
#        128773,  28409, 167703,  48696,  56842,   1806, 127494, 106947, 158372,
#         74378],
#       dtype='int64', length=369301)

# %%
train_data.head()
# Out:
#                                                id1      id2        id3  \
# 0  1366776_189706075_16-23_2023-11-02 22:22:00.042  1366776  189706075
# 1      1366776_89227_16-23_2023-11-01 23:51:24.999  1366776      89227
# 2      1366776_35046_16-23_2023-11-01 00:30:59.797  1366776      35046
# 3    1366776_6275451_16-23_2023-11-02 22:21:32.261  1366776    6275451
# 4      1366776_78053_16-23_2023-11-02 22:21:34.799  1366776      78053
#
#                        id4         id5  y   f1    f2    f3    f4  ...  f357  \
# 0  2023-11-02 22:22:00.042  2023-11-02  0  1.0  None  None  None  ...  None
# 1  2023-11-01 23:51:24.999  2023-11-01  0  1.0  None  None  None  ...  None
# 2  2023-11-01 00:30:59.797  2023-11-01  0  1.0  None  None  None  ...  None
# 3  2023-11-02 22:21:32.261  2023-11-02  0  1.0  None  None  None  ...  None
# 4  2023-11-02 22:21:34.799  2023-11-02  0  1.0  None  None  None  ...  None
#
#       f358 f359  f360   f361 f362               f363    f364 f365  \
# ...

# %%
test_case_01 = test_data[test_data["id2"] == "1000061"]
test_case_02 = test_data[test_data["id2"] == "1000131"]

# %%
a = test_case_01.iloc[0].dropna()
a[a!="0.0"]
# Out:
# id1     False
# id2     False
# id3     False
# id4     False
# id5     False
#         ...
# f354    False
# f355    False
# f356    False
# f357    False
# f358    False
# Name: 138782, Length: 148, dtype: bool

# %%
a
# Out:
# id1     1000061_403431_16-23_2023-11-05 09:28:10.592
# id2                                          1000061
# id3                                           403431
# id4                          2023-11-05 09:28:10.592
# id5                                       2023-11-05
#                             ...
# f354                                            Rest
# f355                              0.0263247126493463
# f356                             -0.0031522605517289
# f357                              0.0011693901721477
# f358                              0.0904507561476268
# Name: 138782, Length: 148, dtype: object

# %%
test_case_01
# Out:
#                                                    id1      id2       id3  \
# 138782    1000061_403431_16-23_2023-11-05 09:28:10.592  1000061    403431
# 138781    1000061_944713_16-23_2023-11-05 09:28:12.529  1000061    944713
# 138795    1000061_430736_16-23_2023-11-05 09:28:12.807  1000061    430736
# 138797     1000061_62395_16-23_2023-11-05 09:28:07.805  1000061     62395
# 138778    1000061_522188_16-23_2023-11-05 09:11:37.242  1000061    522188
# 138783    1000061_803982_16-23_2023-11-05 09:47:52.857  1000061    803982
# 138799   1000061_5420674_16-23_2023-11-05 09:28:04.153  1000061   5420674
# 138793     1000061_72292_16-23_2023-11-05 09:28:07.697  1000061     72292
# 138800  1000061_80107221_16-23_2023-11-05 09:28:12.577  1000061  80107221
# 138802     1000061_86311_16-23_2023-11-05 09:28:12.883  1000061     86311
# 138790    1000061_393281_16-23_2023-11-05 09:28:11.331  1000061    393281
# 138784      1000061_9914_16-23_2023-11-05 09:11:35.557  1000061      9914
# ...

# %%
# add_event.to_csv("../data/other/add_event.csv")
# add_trans.to_csv("../data/other/add_trans.csv")
# offer_metadata.to_csv("../data/other/offer_metadata.csv")
# test_data.to_csv("../data/other/test_data.csv")
# train_data.to_csv("../data/other/train_data.csv")
